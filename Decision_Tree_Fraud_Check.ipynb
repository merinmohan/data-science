# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
 
from sklearn import datasets
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import accuracy_score,confusion_matrix

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
tree_fraud_data  = pd.read_csv('Fraud_check.csv')
tree_fraud_data
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# ...

# %%
tree_fraud_data.columns= ['Undergrad','Marital_status','Taxable_income','City_population','Work_experience','Urban']

# %%
tree_fraud_data.head()
# Out:
#   Undergrad Marital_status  Taxable_income  City_population  Work_experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
tree_fraud_data.loc[tree_fraud_data['Taxable_income']<= 30000,'taxable_income'] = 'Risky'
tree_fraud_data.loc[tree_fraud_data['Taxable_income']>30000,'taxable_income'] = 'Good'

# %%
tree_fraud_data.drop('Taxable_income',axis=1,inplace=True)

# %%
tree_fraud_data
# Out:
#     Undergrad Marital_status  City_population  Work_experience Urban  \
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
#     taxable_income
# 0             Good
# 1             Good
# 2             Good
# 3             Good
# 4             Good
# ...

# %%
tree_fraud_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital_status   600 non-null    object
#  2   City_population  600 non-null    int64
#  3   Work_experience  600 non-null    int64
#  4   Urban            600 non-null    object
#  5   taxable_income   600 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 28.2+ KB

# %%
tree_fraud_data.describe(include='all')
# Out:
#        Undergrad Marital_status  City_population  Work_experience Urban  \
# count        600            600       600.000000       600.000000   600
# unique         2              3              NaN              NaN     2
# top          YES         Single              NaN              NaN   YES
# freq         312            217              NaN              NaN   302
# mean         NaN            NaN    108747.368333        15.558333   NaN
# std          NaN            NaN     49850.075134         8.842147   NaN
# min          NaN            NaN     25779.000000         0.000000   NaN
# 25%          NaN            NaN     66966.750000         8.000000   NaN
# 50%          NaN            NaN    106493.500000        15.000000   NaN
# 75%          NaN            NaN    150114.250000        24.000000   NaN
# max          NaN            NaN    199778.000000        30.000000   NaN
#
#        taxable_income
# count             600
# unique              2
# top              Good
# ...

# %%
le = LabelEncoder()
tree_fraud_data['Undergrad'] = le.fit_transform(tree_fraud_data['Undergrad'])
tree_fraud_data.Undergrad.unique()
# Out:
# array([0, 1])

# %%
tree_fraud_data['Marital_status'] = le.fit_transform(tree_fraud_data['Marital_status'])
tree_fraud_data.Marital_status.unique()
# Out:
# array([2, 0, 1])

# %%
tree_fraud_data['Urban'] = le.fit_transform(tree_fraud_data['Urban'])
tree_fraud_data.Urban.unique()
# Out:
# array([1, 0])

# %%
X = tree_fraud_data.drop('taxable_income',axis=1)

# %%
X
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [600 rows x 5 columns]

# %%
Y = tree_fraud_data[['taxable_income']]
Y
# Out:
#     taxable_income
# 0             Good
# 1             Good
# 2             Good
# 3             Good
# 4             Good
# ..             ...
# 595           Good
# 596           Good
# 597           Good
# 598           Good
# 599           Good
#
# [600 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20,random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((480, 5), (480, 1))

# %%
x_test.shape,y_test.shape
# Out:
# ((120, 5), (120, 1))

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
g, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (8,6), dpi=300)
tree.plot_tree(model,filled=True);

# %%
y_train_pred = model.predict(x_train)
print('Accuracy score:', accuracy_score(y_train,y_train_pred))
# Out:
# Accuracy score: 1.0

# %%
print('Confusion Matrix :\n',confusion_matrix(y_train,y_train_pred))
# Out:
# Confusion Matrix :
#  [[381   0]
#  [  0  99]]

# %%
y_test_pred = model.predict(x_test)
print('Accuracy score:',accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy score: 0.6583333333333333

# %%
print('Confusion Matrix :\n',confusion_matrix(y_test,y_test_pred))
# Out:
# Confusion Matrix :
#  [[71 24]
#  [17  8]]

# %% [markdown]
# ### High training accuracy and low testing accuracy indicates that the model is overfitting.

# %%
#Applying ensemple technique to overcome overfitting

# %% [markdown]
# ### 1.Gradient Boosting

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_train_pred_gbc = gbc.predict(x_train)
print('Accuracy score:',accuracy_score(y_train,y_train_pred_gbc))
# Out:
# Accuracy score: 0.8708333333333333

# %%
y_test_pred_gbc = gbc.predict(x_test)
print('Accuracy score:',accuracy_score(y_test,y_test_pred_gbc))
# Out:
# Accuracy score: 0.7583333333333333

# %% [markdown]
# ### 2.Adaboost

# %%
abc = AdaBoostClassifier()
abc.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_train_pred_abc = abc.predict(x_train)
print('Accuracy score for Training Data:', accuracy_score(y_train,y_train_pred_abc))
# Out:
# Accuracy score for Training Data: 0.8104166666666667

# %%
y_test_pred_abc = abc.predict(x_test)
print('Accuracy score for Testing Data:', accuracy_score(y_test,y_test_pred_abc))
# Out:
# Accuracy score for Testing Data: 0.775

# %%
print('COnfusion Matrix for Training Data:\n', confusion_matrix(y_train,y_train_pred_abc))
# Out:
# COnfusion Matrix for Training Data:
#  [[380   1]
#  [ 90   9]]

# %%
print('COnfusion Matrix for Testing Data:\n', confusion_matrix(y_test,y_test_pred_abc))
# Out:
# COnfusion Matrix for Testing Data:
#  [[93  2]
#  [25  0]]
