# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
airline = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.rename(columns={'ID#':'ID',
                    'Award?':'Award'},inplace=True)
airline
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.shape
# Out:
# (3999, 12)

# %%
airline[airline.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award]
# Index: []

# %%
airline.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
airline.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airline['Qual_miles'].value_counts()
# Out:
# 0       3773
# 1000      17
# 500       15
# 967        4
# 888        4
#         ...
# 4116       1
# 1388       1
# 1896       1
# 3692       1
# 1005       1
# Name: Qual_miles, Length: 164, dtype: int64

# %%
# Standardizing the values
scale = StandardScaler()
airline_scale = scale.fit_transform(airline.iloc[:,1:])

# %%
airline_scale
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
data_scale = pd.DataFrame(airline_scale)
data_scale
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10
# ...

# %%
data_scale.columns = airline.columns.drop('ID')

# %%
data_scale
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Heirarchial Agglomerative Clustering

# %%
dendrogram = sch.dendrogram(sch.linkage(data_scale,method='average'),color_threshold=0.7)

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')

# %%
y_hc = hc.fit_predict(data_scale)
clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 3994         1
# 3995         1
# 3996         1
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %%
airline['Cluster ID'] = clusters

# %%
airline.sort_values('Cluster ID')
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3583  3606   160114         500          1          1          1        71954
# 3235  3257   287033           0          1          1          1        26161
# 2015  2032    53232         888          4          1          1        80696
# 3594  3617    27619           0          4          1          1        83726
# 0        1    28143           0          1          1          1          174
# ...    ...      ...         ...        ...        ...        ...          ...
# 904    915    15835           0          2          1          5       112171
# 2955  2977    61474           0          1          1          4        47717
# 2251  2269   125679           0          3          1          4        68151
# 1878  1895   128302           0          5          1          4       132263
# 3338  3361    84148           0          1          1          5        84148
#
# ...

# %%
airline[airline['Cluster ID']==0]
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2015  2032    53232         888          4          1          1        80696
# 3235  3257   287033           0          1          1          1        26161
# 3583  3606   160114         500          1          1          1        71954
# 3594  3617    27619           0          4          1          1        83726
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2015           65              22100               45               3831
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
# 3594           68              14050               46               1325
#
#       Award  Cluster ID
# 2015      1           0
# 3235      1           0
# 3583      1           0
# 3594      1           0

# %%
airline.groupby('Cluster ID').agg(['mean'])
# Out:
#                      ID       Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean          mean        mean      mean      mean
# Cluster ID
# 0           3128.000000  1.319995e+05  347.000000  2.500000  1.000000
# 1           2015.455893  7.288966e+04  144.193013  2.054034  1.014577
# 2            279.000000  1.704838e+06    0.000000  1.000000  1.000000
# 3           1664.866667  1.380614e+05   78.800000  3.466667  1.000000
#
#            cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo  \
#                 mean          mean        mean              mean
# Cluster ID
# 0           1.000000  65634.250000   69.250000      19960.000000
# 1           1.000754  16806.654184   11.476753        439.180699
# 2           1.000000  17108.000000   32.000000       4823.000000
# 3           4.066667  93927.866667   28.066667        506.666667
#
#            Flight_trans_12 Days_since_enroll     Award
#                       mean              mean      mean
# Cluster ID
# ...

# %% [markdown]
# ### Heirarchial Agglomerative Clustering Using Normalized data

# %%
airline_1 = data = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
airline_1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_1.rename(columns={'ID#':'ID',
                    'Award?':'Award'},inplace=True)
airline_1
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
norm = StandardScaler()
airline_norm = norm.fit_transform(airline_1.iloc[:,1:])

# %%
dendrogram_norm = sch.dendrogram(sch.linkage(airline_norm,method='complete'),color_threshold=0.7)

# %%
hc_norm = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'complete')

# %%
y_hc_norm = hc_norm.fit_predict(airline_norm)
clusters_1 = pd.DataFrame(y_hc_norm,columns=['Clusters'])

# %%
clusters_1
# Out:
#       Clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
airline_1['Clusters'] = clusters_1

# %%
airline_1
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ## K Means

# %% [markdown]
# #### Elbow plot for Number of Clusters

# %%
airline_2 = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
airline_2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_2.rename(columns={'ID#':'ID',
                    'Award?':'Award'},inplace=True)
airline_2
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(airline_scale)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Standardized data')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
norm = MinMaxScaler()
airline_norm_df = norm.fit_transform(data.iloc[:,1:])

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(airline_norm_df)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Normalized data')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4,random_state=42)
kmeans.fit(airline_norm_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans.inertia_
# Out:
# 450.23446162466394

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
airline_2['Cluster'] = kmeans.labels_

# %%
airline_2.sort_values('Cluster')
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 2421  2440    41062           0          1          2          1         8275
# 2424  2443    14336           0          1          1          1            0
# 2426  2445   121390           0          1          1          1         8500
# 2429  2448    68012           0          1          1          1          247
# ...    ...      ...         ...        ...        ...        ...          ...
# 2309  2327    13232           0          1          1          1         8668
# 3377  3400    23720           0          1          1          1         4000
# 445    451   106773           0          1          1          1        12900
# 2344  2362    42107         888          1          1          1         3600
# 1388  1402   156041           0          2          1          1         5644
#
# ...

# %% [markdown]
# ## DBSCAN

# %%
airline_3=data
airline_3
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_3.drop(['Clusters'],axis = 1,inplace=True)

# %%
airline_3.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
airline_3_db = airline_3.drop('ID',axis=1)

# %%
airline_3_db
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
sacle=MinMaxScaler()
airline_3_norm=scale.fit_transform(airline_3.iloc[:,:])
airline_3_norm_df=pd.DataFrame(airline_3_norm,columns=airline_3.columns)
airline_3_norm_df
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
dbscan = DBSCAN(eps = 0.5, min_samples=33)
dbscan.fit(airline_3_norm_df)
# Out:
# DBSCAN(min_samples=33)

# %%
dbscan.labels_
# Out:
# array([ 0,  0,  0, ..., -1,  0,  0], dtype=int64)

# %%
airline_3['Cluster'] = dbscan.labels_

# %%
airline_3.sort_values('Cluster')
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1999  2016   327126        1452          5          1          1        97997
# 2057  2074   126886           0          2          1          1         9120
# 2058  2075    42342           0          1          1          1        11408
# 2059  2076    58898           0          1          1          1        23050
# 2061  2078    77225           0          4          1          1        30646
# ...    ...      ...         ...        ...        ...        ...          ...
# 2237  2255     3350           0          1          1          1           65
# 2236  2254    46882           0          1          1          1            0
# 2235  2253    14620           0          1          1          1            0
# 2259  2277    30686           0          1          1          1         6161
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_3.groupby('Cluster').agg(['mean'])
# Out:
#                   ID       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                 mean          mean        mean      mean      mean      mean
# Cluster
# -1       1861.661175  95354.744269  206.416189   2.51755  1.020774   1.01755
#  0       2369.101077  23281.908036    0.000000   1.00000  1.000000   1.00000
#
#           Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                  mean        mean              mean            mean
# Cluster
# -1       23959.008596   15.090616        647.463109        1.923352
#  0        1382.508699    3.531897         26.550124        0.101906
#
#         Days_since_enroll     Award
#                      mean      mean
# Cluster
# -1            4413.957020  0.530444
#  0            3435.253521  0.000000
